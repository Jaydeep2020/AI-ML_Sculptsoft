# %% [markdown]
# # Text Splitters in LangChain

# %% [markdown]
# ### 1) Length Based Text Splitter

# %%
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader("data/Junior AI_ML Developer.pdf")

# %%
# %pip install pypdf
# Out:
# Requirement already satisfied: pypdf in c:\users\jaydeep\appdata\local\python\pythoncore-3.14-64\lib\site-packages (6.15.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: C:\Users\Jaydeep\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
text = loader.load()

# %%
splitter = CharacterTextSplitter(
    chunk_size=300,
    chunk_overlap=0,
    separator=" ",
)

# %%
result = splitter.split_documents(text)

# %%
result[0]
# Out:
# Document(metadata={'producer': 'Skia/PDF m140 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Junior AI/ML Developer', 'source': 'data/Junior AI_ML Developer.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='Junior AI/ML Developer \n \nJob Overview: \nWe are looking for a passionate and curious Junior AI/ML Developer to join our team and \nsupport\n \ndevelopment\n \nin\n \nLarge\n \nLanguage\n \nModels\n \n(LLMs)\n \nand\n \nComputer\n \nVision\n \ndomains.\n \nThe\n \nideal\n \ncandidate\n \nshould\n \nhave\n \na\n \nsolid')
